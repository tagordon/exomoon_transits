# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.append('../binary')
import system

# %%
t = np.linspace(90.5, 92, 5000)

t0p = 0
ep = 0.0
Pp = 365
Op = 0.0 * np.pi / 180
wp = 0.0 * np.pi / 180
ip = 90.0001 * np.pi / 180
mp = 10.0

t0m = -1.35
em = 0.0
Pm = 1
Om = 0.0 * np.pi / 180
wm = 90.0 * np.pi / 180
im = 90.0 * np.pi / 180
mm = 5.0

# %%
star = system.star(1, 0.5, 0.5)
planet = system.rock(0.1, 10, t0p, ep, Pp, Op, wp, ip)
moon = system.rock(0.05, 5, t0m, em, Pm, Om, wm, im)
sys = system.system(star, planet, moon)
# %time sys.compute(t)
# Out:
# CPU times: user 7.31 ms, sys: 3.34 ms, total: 10.7 ms
# Wall time: 9.32 ms

# %%
plt.plot(t, sys.lightcurve())

# %%
plt.plot(t, sys.derivatives());
