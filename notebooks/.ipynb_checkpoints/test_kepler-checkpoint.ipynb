# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.append('../binary')

# %%
from kep import kepler_solve_RPP

# %%
M = np.linspace(0, 2 * np.pi, 100000)
e = 0.8

# %time cosf, sinf, f_e, f_M = kepler_solve(M, e)
# Out:
# CPU times: user 21.3 ms, sys: 3.84 ms, total: 25.1 ms
# Wall time: 25.4 ms

# %%
from exoplanet_core import kepler

# %%
# %time sinf_xo, cosf_xo = kepler(M, e)
# Out:
# CPU times: user 9.52 ms, sys: 207 µs, total: 9.73 ms
# Wall time: 9.63 ms

# %%
plt.plot(M, cosf)
plt.plot(M, cosf_xo)

plt.plot(M, sinf)
plt.plot(M, sinf_xo)

# %%
plt.plot(M, cosf - cosf_xo)
