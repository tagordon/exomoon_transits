# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.append('../binary')

# %%
from exoplanet_core import driver

# %%
from kep import kepler_solve_RPP, kepler_solve

# %%
M = np.linspace(0, 2 * np.pi, 100000)
e = 0.1

# %time cosf, sinf = kepler_solve_RPP(M, e)
# Out:
# CPU times: user 9.7 ms, sys: 1.16 ms, total: 10.9 ms
# Wall time: 12.9 ms

# %%
from exoplanet_core import kepler

# %%
# %time sinf_xo, cosf_xo = kepler(M, e)
# Out:
# CPU times: user 10.3 ms, sys: 311 µs, total: 10.6 ms
# Wall time: 11.3 ms

# %%
plt.plot(M, cosf)
plt.plot(M, cosf_xo, '--')

plt.plot(M, sinf)
plt.plot(M, sinf_xo, '--')

plt.axvline(3 * np.pi / 2)

# %%
plt.plot(M, cosf - cosf_xo)
